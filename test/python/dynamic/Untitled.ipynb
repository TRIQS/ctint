# %%
from pytriqs.gf.local import *
from pytriqs.archive import *
from pytriqs.plot.mpl_interface import *
import itertools
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mydir = "/home/jvucicev/TRIQS/build/ctint/test/python/dynamic"
A = HDFArchive("%s/all.output.h5"%(mydir),'r')
B = HDFArchive("all.output.h5",'r')

# %%
oplot(A['G_iw']['up'].real,'-', ms=10,label ="ReA")
oplot(B['G_iw']['up'].real,'-', ms=10,label ="ReB")
oplot(A['G_iw']['up'].imag,'-', ms=10,label ="ImA")
oplot(B['G_iw']['up'].imag,'-', ms=10,label ="ImB")

# %%
oplot((A['G_iw']['up']-B['G_iw']['up']).real,'-', ms=10,label ="Re(A-B)")
oplot((A['G_iw']['up']-B['G_iw']['up']).imag,'-', ms=10,label ="Im(A-B)")

# %%
N_sites = 16
N_s = 2
delta = 0.1
alpha = [ [ [ 0.5 + delta*(-1)**(s+sig) for s in range(N_s)] for i in range(N_sites)] for sig in range(2) ]
for a in alpha:
  print "------"
  for b in a:
    print b
for i in range(2):
  for j in range(N_sites):  
    for k in range(N_s):
      print i,j,k,":",alpha[i][j][k]
# Out:
# ------
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# [0.6, 0.4]
# ------
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# [0.4, 0.6]
# 0 0 0 : 0.6
# 0 0 1 : 0.4
# 0 1 0 : 0.6
# 0 1 1 : 0.4
# 0 2 0 : 0.6
# 0 2 1 : 0.4
# 0 3 0 : 0.6
# 0 3 1 : 0.4
# 0 4 0 : 0.6
# 0 4 1 : 0.4
# 0 5 0 : 0.6
# 0 5 1 : 0.4
# 0 6 0 : 0.6
# 0 6 1 : 0.4
# 0 7 0 : 0.6
# 0 7 1 : 0.4
# 0 8 0 : 0.6
# 0 8 1 : 0.4
# 0 9 0 : 0.6
# 0 9 1 : 0.4
# 0 10 0 : 0.6
# 0 10 1 : 0.4
# 0 11 0 : 0.6
# 0 11 1 : 0.4
# 0 12 0 : 0.6
# 0 12 1 : 0.4
# 0 13 0 : 0.6
# 0 13 1 : 0.4
# 0 14 0 : 0.6
# 0 14 1 : 0.4
# 0 15 0 : 0.6
# 0 15 1 : 0.4
# 1 0 0 : 0.4
# 1 0 1 : 0.6
# 1 1 0 : 0.4
# 1 1 1 : 0.6
# 1 2 0 : 0.4
# 1 2 1 : 0.6
# 1 3 0 : 0.4
# ...
